# %%
gym
notebook
matplotlib
gym[classic_control]
tensorflow
tqdm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b674b961c4d2> in <module>
# ----> 1 gym
#       2 notebook
#       3 matplotlib
#       4 gym[classic_control]
#       5 tensorflow
#
# NameError: name 'gym' is not defined
